# %%
import pandas as pd
import os

# Load data
df = pd.read_csv("../data/raw/soil_india_shc.csv")

# Basic info
print("Shape:", df.shape)
print("\nData Types:\n", df.dtypes)
print("\nMissing Values:\n", df.isna().sum())

# Basic stats
display(df.describe())

# Unique soil types and crops
print("\nSoil types:", df['Soil_Type'].unique())
print("Crop types:", df['Crop_Suitability'].unique())
# Out:
# Shape: (50, 12)
#
# Data Types:
#  State                object
# District             object
# Farmer_ID            object
# Soil_Type            object
# pH                  float64
# EC                  float64
# OC                  float64
# N                     int64
# P                     int64
# K                     int64
# Moisture              int64
# Crop_Suitability     object
# dtype: object
#
# Missing Values:
#  State               0
# District            0
# Farmer_ID           0
# Soil_Type           0
# pH                  0
# EC                  0
# OC                  0
# N                   0
# P                   0
# K                   0
# Moisture            0
# Crop_Suitability    0
# dtype: int64
#               pH         EC         OC           N          P          K  \
# count  50.000000  50.000000  50.000000   50.000000  50.000000   50.00000
# mean    6.186000   0.790600   0.969000  273.560000  23.820000  139.66000
# ...
