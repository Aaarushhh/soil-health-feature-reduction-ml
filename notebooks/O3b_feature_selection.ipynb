# %%
import pandas as pd

df = pd.read_csv('../data/raw/soil_india_shc.csv')
df_reduced = df.drop(columns=correlated_features)

df_reduced.to_csv('../data/processed/soil_reduced_features.csv', index=False)
print("✅ Reduced dataset saved with shape:", df_reduced.shape)
# Out:
# ✅ Reduced dataset saved with shape: (50, 12)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8,6))
sns.heatmap(corr, annot=True, cmap='YlGnBu', linewidths=0.3)
plt.title('Feature Correlation Heatmap')
plt.show()

# %%
threshold = 0.8  # Correlation cutoff
correlated_features = set()

for i in range(len(corr.columns)):
    for j in range(i):
        if abs(corr.iloc[i, j]) > threshold:
            colname = corr.columns[i]
            correlated_features.add(colname)

print("🔎 Highly correlated features to drop:", correlated_features)
# Out:
# 🔎 Highly correlated features to drop: set()

# %%
import pandas as pd

# Load correlation matrix created by Member 1
corr = pd.read_csv('../data/processed/soil_correlation_matrix.csv', index_col=0)



corr.head()
# Out:
#           pH        EC        OC         N         P         K  Moisture
# pH  1.000000  0.225211 -0.246913 -0.072417 -0.456064 -0.064733 -0.122589
# EC  0.225211  1.000000 -0.101240 -0.086067 -0.128556 -0.007703  0.036638
# OC -0.246913 -0.101240  1.000000  0.166687  0.053458  0.172059 -0.142888
# N  -0.072417 -0.086067  0.166687  1.000000 -0.271377 -0.050869  0.158166
# P  -0.456064 -0.128556  0.053458 -0.271377  1.000000  0.023045 -0.044034
